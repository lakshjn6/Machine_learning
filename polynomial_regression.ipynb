# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x=6*np.random.rand(200,1)

# %%
x
# Out:
# array([[2.36506237],
#        [5.31495812],
#        [4.1296773 ],
#        [2.5899675 ],
#        [1.65669495],
#        [0.77126158],
#        [0.76659678],
#        [1.49244205],
#        [3.26554497],
#        [1.12081392],
#        [3.15086639],
#        [3.99683287],
#        [1.0480227 ],
#        [2.87524602],
#        [4.76605877],
#        [1.21375429],
#        [0.40132491],
#        [3.82975085],
#        [2.87801629],
#        [5.5224794 ],
#        [3.74847928],
#        [4.86234479],
#        [0.80165511],
#        [4.79999551],
#        [4.39581633],
#        [0.64732747],
#        [4.83148218],
#        [3.53369555],
#        [3.0070333 ],
#        [3.63358826],
#        [5.29131742],
#        [5.05266193],
#        [4.47183087],
#        [1.7200577 ],
#        [0.29213871],
#        [4.90346769],
#        [5.11222096],
#        [5.45205723],
#        [0.87249474],
#        [1.51771125],
#        [0.69732539],
#        [2.42939213],
#        [5.77067128],
# ...

# %%
y=0.6*x**2+0.8*x+2+np.random.randn(200,1)

# %%
y
# Out:
# array([[ 7.31409752],
#        [22.37913028],
#        [15.16656176],
#        [ 8.40508349],
#        [ 5.3090448 ],
#        [ 1.70287318],
#        [ 2.36157   ],
#        [ 4.98588975],
#        [10.00086986],
#        [ 4.5289475 ],
#        [10.59579878],
#        [13.58681085],
#        [ 2.92098039],
#        [ 8.11898838],
#        [20.90027729],
#        [ 3.47968273],
#        [ 1.18232361],
#        [13.08623151],
#        [ 9.55643618],
#        [22.63874017],
#        [12.82686916],
#        [21.08907987],
#        [ 2.53523825],
#        [22.33609339],
#        [18.41729596],
#        [ 2.68615424],
#        [20.54036091],
#        [12.12365844],
#        [ 9.57966142],
#        [12.91396027],
#        [24.05255083],
#        [22.20159024],
#        [17.06625479],
#        [ 6.45946302],
#        [ 0.92920865],
#        [21.16568369],
#        [21.25466635],
#        [24.86418496],
#        [ 4.711729  ],
#        [ 6.03944644],
#        [ 3.87865905],
# ...

# %%
poly=PolynomialFeatures(degree=2)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=2)

# %%
x_train
# Out:
# array([[1.47125316],
#        [4.92648782],
#        [0.18582283],
#        [0.26986446],
#        [1.35757932],
#        [4.95826145],
#        [2.42939213],
#        [0.28541852],
#        [4.07268948],
#        [0.77126158],
#        [0.59880563],
#        [5.16090735],
#        [3.99683287],
#        [2.7765411 ],
#        [4.39581633],
#        [0.84727997],
#        [4.57441568],
#        [3.26554497],
#        [5.37668332],
#        [4.4740017 ],
#        [3.0070333 ],
#        [1.70686264],
#        [2.40123808],
#        [5.77067128],
#        [5.91537607],
#        [1.53706151],
#        [0.89704057],
#        [5.9563671 ],
#        [1.05002657],
#        [4.33421482],
#        [2.11709577],
#        [2.01274981],
#        [4.84857321],
#        [5.98863587],
#        [5.31495812],
#        [2.30848566],
#        [1.69019728],
#        [4.34737094],
#        [5.71475009],
#        [3.61329752],
#        [0.11468656],
#        [5.11222096],
#        [2.85856645],
# ...

# %%
x_train_trans=poly.fit_transform(x_train)

# %%
x_train_trans[0]
# Out:
# array([1.        , 1.47125316, 2.16458586])

# %%
lr.fit(x_train_trans,y_train)
# Out:
# LinearRegression()

# %%
x_test_trans=poly.transform(x_test)

# %%
y_pred=lr.predict(x_test_trans)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9776229665998041

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual Values')  # Actual test points
plt.scatter(x_test, y_pred, color='red', label='Predicted Values')  # Predicted test points
plt.plot(
    np.sort(x_test, axis=0), 
    lr.predict(poly.transform(np.sort(x_test, axis=0))), 
    color='green', 
    label='Prediction Curve'
)
plt.title("x_test vs y_pred (Parabola)")
plt.xlabel("x_test")
plt.ylabel("y_pred")
plt.legend()
plt.show()
