# %%
import pandas as pd

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
df=pd.read_csv("C:\\Users\BIT\\OneDrive\\Desktop\\placement.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_10784\648005961.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df=pd.read_csv("C:\\Users\BIT\\OneDrive\\Desktop\\placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.cgpa,df.package)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.cgpa,df.package,random_state=2,train_size=0.8)

# %%
x_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 160 entries, 137 to 168
# Series name: cgpa
# Non-Null Count  Dtype
# --------------  -----
# 160 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 40 entries, 112 to 53
# Series name: cgpa
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     float64
# dtypes: float64(1)
# memory usage: 640.0 bytes

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 160 entries, 137 to 168
# Series name: package
# Non-Null Count  Dtype
# --------------  -----
# 160 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
x_train=x_train.values.reshape(-1,1)
y_train=y_train.values.reshape(-1,1)

# %%
x_train
# Out:
# array([[7.14],
#        [8.93],
#        [5.42],
#        [5.1 ],
#        [7.77],
#        [6.76],
#        [6.89],
#        [6.68],
#        [7.91],
#        [7.89],
#        [8.71],
#        [7.95],
#        [6.61],
#        [6.26],
#        [6.53],
#        [6.42],
#        [5.11],
#        [6.09],
#        [6.93],
#        [7.04],
#        [5.94],
#        [6.05],
#        [5.83],
#        [5.95],
#        [9.31],
#        [5.58],
#        [7.88],
#        [6.13],
#        [7.76],
#        [4.85],
#        [6.19],
#        [8.6 ],
#        [6.07],
#        [7.18],
#        [5.12],
#        [7.39],
#        [8.25],
#        [8.28],
#        [7.13],
#        [7.35],
#        [5.66],
#        [5.99],
#        [8.01],
#        [7.14],
#        [6.34],
#        [6.89],
#        [5.42],
#        [6.47],
#        [7.69],
#        [7.4 ],
#        [7.28],
#        [5.95],
#        [7.38],
#        [6.93],
#        [8.99],
#        [7.36],
#        [7.08],
#        [5.38],
#        [7.56],
#        [8.22],
#        [5.84],
#        [6.78],
#        [7.19],
#        [7.28],
#        [6.79],
#        [6.12],
#        [6.85],
#        [8.2 ],
#        [6.84],
#        [7.37],
#        [6.22],
#        [6.61],
#        [5.23],
#        [7.21],
#        [6.85],
#        [6.19],
#        [7.3 ],
#        [6.17],
#        [5.89],
#        [8.09],
#        [7.11],
#        [4.26],
#        [6.94],
#        [5.98],
#        [6.71],
#        [7.33],
#        [9.06],
#        [6.1 ],
#        [5.48],
#        [6.1 ],
#        [7.56],
#        [7.29],
#        [5.84],
#        [7.48],
#        [7.61],
#        [5.79],
#        [5.61],
#        [7.34],
#        [9.38],
#        [7.91],
#        [6.94],
#        [7.94],
#        [8.31],
#        [6.96],
#        [6.93],
#        [7.11],
#        [8.44],
#        [8.18],
#        [6.66],
#        [8.44],
#        [7.12],
#        [6.3 ],
#        [5.84],
#        [6.98],
#        [7.63],
#        [5.64],
#        [7.43],
#        [8.87],
#        [7.84],
#        [5.84],
#        [9.58],
#        [8.37],
#        [7.63],
#        [6.31],
#        [6.5 ],
#        [8.11],
#        [6.07],
#        [4.73],
#        [7.3 ],
#        [6.51],
#        [7.28],
#        [6.92],
#        [6.35],
#        [8.62],
#        [7.05],
#        [9.26],
#        [6.33],
#        [6.22],
#        [6.94],
#        [5.13],
#        [8.13],
#        [5.9 ],
#        [9.04],
#        [6.06],
#        [7.57],
#        [8.1 ],
#        [9.16],
#        [5.84],
#        [7.89],
#        [6.63],
#        [7.09],
#        [5.53],
#        [6.75],
#        [7.62],
#        [6.97],
#        [7.66],
#        [6.14],
#        [7.78],
#        [7.25],
#        [8.65]])

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[0.55795197]])

# %%
lr.intercept_
# Out:
# array([-0.89611192])

# %%
x_test=x_test.values.reshape(-1,1)

# %%
plt.scatter(df.cgpa,df.package)
plt.plot(x_test,lr.predict(x_test),color='r')

# %%
from sklearn.metrics import r2_score

# %%
y_test=y_test.values.reshape(-1,1)

# %%
r2_score(y_test,lr.predict(x_test))
# Out:
# 0.780730147510384
